# %%
import lmod
await lmod.load('deepretinotopy/1.0.8')
import time

# !deepRetinotopy

# %%
start_time = time.time()
# !deepRetinotopy -s /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/ \
                -t /neurodesktop-storage/HCPpipelines/global/templates/standard_mesh_atlases/resample_fsaverage/ \
                -d nyu \
                -m "polarAngle,eccentricity"
end_time = time.time()
print(f"Runtime: {end_time - start_time:.6f} seconds")
# Out:
# --------------------------------------------------------------------------------
# DeepRetinotopy: retinotopic mapping using deep learning
# --------------------------------------------------------------------------------
# Directories and parameters:
#
# Path to FreeSurfer directory: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/
# Path to fs_LR-deformed_to-fsaverage template surfaces: /neurodesktop-storage/HCPpipelines/global/templates/standard_mesh_atlases/resample_fsaverage/
# Dataset name: nyu
# Maps: polarAngle eccentricity
# --------------------------------------------------------------------------------
# Generating retinotopic maps for the left hemisphere
# --------------------------------------------------------------------------------
# [Step 1] Generating mid-thickness surface and curvature data...
# Hemisphere: lh
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# --------------------------------------------------------------------------------
# Map: polarAngle
# --------------------------------------------------------------------------------
# [Step 2] Retinotopy prediction...
# Processing...
# Done!
# [Step 2.1] Loading the dataset
# Dataset loaded
# Time elapsed: 0.34723978117108345 minutes
# [Step 2.2] Generating predictions with pre-trained models
# Loading model 1
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj001/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj006/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj007/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj014/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj019/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj023/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj042/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj045/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj055/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj056/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj057/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj062/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj071/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj076/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj079/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj081/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj083/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj084/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj086/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj088/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj091/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj094/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj095/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj104/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj114/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj115/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj116/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj117/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj118/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj120/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj126/deepRetinotopy/
# Predictions from model 1 were saved
# Time elapsed: 8.301112074404955 minutes
# --------------------------------------------------------------------------------
# [Step 3] Resampling predictions to native space...
# Model: model
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# Transforming polar angle map of the left hemisphere...
# polarAngle predictions resampling for lh is done!
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Map: eccentricity
# --------------------------------------------------------------------------------
# [Step 2] Retinotopy prediction...
# Processing...
# Done!
# [Step 2.1] Loading the dataset
# Dataset loaded
# Time elapsed: 0.30796582996845245 minutes
# [Step 2.2] Generating predictions with pre-trained models
# Loading model 1
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj001/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj006/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj007/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj014/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj019/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj023/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj042/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj045/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj055/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj056/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj057/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj062/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj071/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj076/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj079/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj081/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj083/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj084/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj086/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj088/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj091/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj094/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj095/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj104/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj114/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj115/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj116/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj117/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj118/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj120/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj126/deepRetinotopy/
# Predictions from model 1 were saved
# Time elapsed: 8.262015491724014 minutes
# --------------------------------------------------------------------------------
# [Step 3] Resampling predictions to native space...
# Model: model
# eccentricity predictions resampling for lh is done!
# --------------------------------------------------------------------------------
# Generating retinotopic maps for the right hemisphere
# --------------------------------------------------------------------------------
# [Step 1] Generating mid-thickness surface and curvature data...
# Hemisphere: rh
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# Mid-thickness surface and curvature data is already available.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Resampled curvature data is already available.
# Execution time: 0 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj076/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj076/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0068, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0066, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0196, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0197, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0212, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0513, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2528, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0195, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0192, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0196, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0196, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1696968
# min=0.000, parallel=0.0058, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 10306.698359
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj076/surf/rh.graymid...
# surface expansion took 22 minutes and 28 seconds.
# total integrated curvature = -2.494*4pi (-31.338) --> 3 handles
# ICI = 206.4, FI = 1885.4, variation=30826.056
# done.ng Gaussian curvature to sub-wlsubj076/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj076/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj076/surf/rh.midthickness.surf.gii.temp8365.white.surf.gii as a surface
# Saving sub-wlsubj076/surf/rh.midthickness.surf.gii.temp8365.pial.surf.gii as a surface
# Saving sub-wlsubj076/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 22 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj079/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj079/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0069, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0066, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0211, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0211, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0222, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0477, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2736, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0210, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0206, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0211, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0211, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0066, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1625940
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 8645.208711
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj079/surf/rh.graymid...
# surface expansion took 18 minutes and 41 seconds.
# total integrated curvature = -6.289*4pi (-79.024) --> 7 handles
# ICI = 166.9, FI = 1640.8, variation=26446.233
# done.ng Gaussian curvature to sub-wlsubj079/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj079/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj079/surf/rh.midthickness.surf.gii.temp11231.white.surf.gii as a surface
# Saving sub-wlsubj079/surf/rh.midthickness.surf.gii.temp11231.pial.surf.gii as a surface
# Saving sub-wlsubj079/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 18 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj081/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj081/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0069, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0066, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0233, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0233, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0246, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0568, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2980, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0231, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0227, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0232, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0232, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1602508
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 8010.365101
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj081/surf/rh.graymid...
# surface expansion took 17 minutes and 11 seconds.
# total integrated curvature = 0.350*4pi (4.404) --> 1 handles
# ICI = 162.9, FI = 1467.3, variation=24044.054
# done.ng Gaussian curvature to sub-wlsubj081/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj081/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj081/surf/rh.midthickness.surf.gii.temp13870.white.surf.gii as a surface
# Saving sub-wlsubj081/surf/rh.midthickness.surf.gii.temp13870.pial.surf.gii as a surface
# Saving sub-wlsubj081/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 17 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj083/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj083/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0064, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0062, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0199, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0198, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0212, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0585, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2952, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0198, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0195, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0198, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0198, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0058, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0063, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1634688
# min=0.000, parallel=0.0058, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9081.540903
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj083/surf/rh.graymid...
# surface expansion took 19 minutes and 4 seconds.
# total integrated curvature = 10.535*4pi (132.393) --> -10 handles
# ICI = 201.9, FI = 1686.5, variation=28015.573
# done.ng Gaussian curvature to sub-wlsubj083/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj083/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj083/surf/rh.midthickness.surf.gii.temp16788.white.surf.gii as a surface
# Saving sub-wlsubj083/surf/rh.midthickness.surf.gii.temp16788.pial.surf.gii as a surface
# Saving sub-wlsubj083/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 19 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj084/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj084/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0070, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0069, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0225, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0225, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0237, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0610, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2983, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0223, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0219, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0224, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0223, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0062, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0069, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1632272
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9210.767497
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj084/surf/rh.graymid...
# surface expansion took 18 minutes and 50 seconds.
# total integrated curvature = 8.961*4pi (112.605) --> -8 handles
# ICI = 217.6, FI = 1670.4, variation=28449.374
# done.ng Gaussian curvature to sub-wlsubj084/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj084/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj084/surf/rh.midthickness.surf.gii.temp19674.white.surf.gii as a surface
# Saving sub-wlsubj084/surf/rh.midthickness.surf.gii.temp19674.pial.surf.gii as a surface
# Saving sub-wlsubj084/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 19 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj086/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj086/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0063, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0062, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0209, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0209, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0220, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0547, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2862, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0207, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0203, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0208, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0208, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0056, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1640148
# min=0.000, parallel=0.0056, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9010.641813
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj086/surf/rh.graymid...
# surface expansion took 19 minutes and 19 seconds.
# total integrated curvature = 3.371*4pi (42.357) --> -2 handles
# ICI = 181.4, FI = 1611.1, variation=26458.016
# done.ng Gaussian curvature to sub-wlsubj086/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj086/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj086/surf/rh.midthickness.surf.gii.temp22641.white.surf.gii as a surface
# Saving sub-wlsubj086/surf/rh.midthickness.surf.gii.temp22641.pial.surf.gii as a surface
# Saving sub-wlsubj086/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 19 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj088/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj088/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0069, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0067, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0215, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0214, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0228, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0524, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2652, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0213, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0209, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0214, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0214, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0062, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0067, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1670700
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9878.097370
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj088/surf/rh.graymid...
# surface expansion took 21 minutes and 6 seconds.
# total integrated curvature = 3.372*4pi (42.378) --> -2 handles
# ICI = 196.6, FI = 1715.5, variation=28295.890
# done.ng Gaussian curvature to sub-wlsubj088/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj088/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj088/surf/rh.midthickness.surf.gii.temp26049.white.surf.gii as a surface
# Saving sub-wlsubj088/surf/rh.midthickness.surf.gii.temp26049.pial.surf.gii as a surface
# Saving sub-wlsubj088/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 21 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj091/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj091/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0070, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0068, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0224, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0224, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0235, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0529, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2863, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0222, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0218, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0223, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0223, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0063, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0068, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1621076
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 8584.720411
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj091/surf/rh.graymid...
# surface expansion took 18 minutes and 17 seconds.
# total integrated curvature = 8.425*4pi (105.868) --> -7 handles
# ICI = 199.2, FI = 1580.4, variation=26659.905
# done.ng Gaussian curvature to sub-wlsubj091/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj091/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# ...
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj118/surf/rh.graymid...
# surface expansion took 19 minutes and 57 seconds.
# total integrated curvature = -1.868*4pi (-23.476) --> 3 handles
# ICI = 192.3, FI = 1854.2, variation=29945.493
# done.ng Gaussian curvature to sub-wlsubj118/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj118/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj118/surf/rh.midthickness.surf.gii.temp53284.white.surf.gii as a surface
# Saving sub-wlsubj118/surf/rh.midthickness.surf.gii.temp53284.pial.surf.gii as a surface
# Saving sub-wlsubj118/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 20 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj120/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj120/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0067, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0210, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0210, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0223, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0523, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2619, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0208, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0204, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0210, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0209, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1663780
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9629.493090
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj120/surf/rh.graymid...
# surface expansion took 20 minutes and 43 seconds.
# total integrated curvature = -15.825*4pi (-198.864) --> 17 handles
# ICI = 165.5, FI = 1731.3, variation=27675.926
# done.ng Gaussian curvature to sub-wlsubj120/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj120/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj120/surf/rh.midthickness.surf.gii.temp56469.white.surf.gii as a surface
# Saving sub-wlsubj120/surf/rh.midthickness.surf.gii.temp56469.pial.surf.gii as a surface
# Saving sub-wlsubj120/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 21 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj126/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj126/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0234, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0518, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2778, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0225, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0221, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0225, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0054, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0058, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1632096
# min=0.000, parallel=0.0053, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 8572.524384
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj126/surf/rh.graymid...
# surface expansion took 18 minutes and 41 seconds.
# total integrated curvature = -12.790*4pi (-160.730) --> 14 handles
# ICI = 154.5, FI = 1521.4, variation=24654.670
# done.ng Gaussian curvature to sub-wlsubj126/surf/rh.graymid.K...
# done.ng mean curvature to sub-wlsubj126/surf/rh.graymid.H...
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj126/surf/rh.midthickness.surf.gii.temp59342.white.surf.gii as a surface
# Saving sub-wlsubj126/surf/rh.midthickness.surf.gii.temp59342.pial.surf.gii as a surface
# Saving sub-wlsubj126/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 18 minutes
# --------------------------------------------------------------------------------
# Map: polarAngle
# --------------------------------------------------------------------------------
# [Step 2] Retinotopy prediction...
# Processing...
# Done!
# [Step 2.1] Loading the dataset
# Dataset loaded
# Time elapsed: 0.30426717549562454 minutes
# [Step 2.2] Generating predictions with pre-trained models
# Loading model 1
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj001/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj006/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj007/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj014/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj019/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj023/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj042/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj045/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj055/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj056/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj057/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj062/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj071/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj076/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj079/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj081/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj083/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj084/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj086/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj088/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj091/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj094/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj095/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj104/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj114/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj115/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj116/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj117/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj118/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj120/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj126/deepRetinotopy/
# Predictions from model 1 were saved
# Time elapsed: 8.003226980566978 minutes
# --------------------------------------------------------------------------------
# [Step 3] Resampling predictions to native space...
# Model: model
# polarAngle predictions resampling for rh is done!
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Map: eccentricity
# --------------------------------------------------------------------------------
# [Step 2] Retinotopy prediction...
# Processing...
# Done!
# [Step 2.1] Loading the dataset
# Dataset loaded
# Time elapsed: 0.2979503944516182 minutes
# [Step 2.2] Generating predictions with pre-trained models
# Loading model 1
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj001/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj006/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj007/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj014/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj019/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj023/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj042/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj045/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj055/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj056/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj057/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj062/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj071/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj076/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj079/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj081/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj083/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj084/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj086/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj088/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj091/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj094/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj095/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj104/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj114/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj115/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj116/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj117/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj118/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj120/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_white2mid/sub-wlsubj126/deepRetinotopy/
# Predictions from model 1 were saved
# Time elapsed: 8.008569292724133 minutes
# --------------------------------------------------------------------------------
# [Step 3] Resampling predictions to native space...
# Model: model
# eccentricity predictions resampling for rh is done!
# --------------------------------------------------------------------------------
# All done!
# Runtime: 23934.695371 seconds
