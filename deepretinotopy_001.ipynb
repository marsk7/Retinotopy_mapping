# %%
import lmod
await lmod.load('deepretinotopy/1.0.8')
import time

# !deepRetinotopy

# %%
start_time = time.time()
# !deepRetinotopy -s /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/ \
                -t /neurodesktop-storage/HCPpipelines/global/templates/standard_mesh_atlases/resample_fsaverage/ \
                -d nyu \
                -m "polarAngle,eccentricity"
end_time = time.time()
print(f"Runtime: {end_time - start_time:.6f} seconds")
# Out:
# --------------------------------------------------------------------------------
# DeepRetinotopy: retinotopic mapping using deep learning
# --------------------------------------------------------------------------------
# Directories and parameters:
#
# Path to FreeSurfer directory: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/
# Path to fs_LR-deformed_to-fsaverage template surfaces: /neurodesktop-storage/HCPpipelines/global/templates/standard_mesh_atlases/resample_fsaverage/
# Dataset name: nyu
# Maps: polarAngle eccentricity
# --------------------------------------------------------------------------------
# Generating retinotopic maps for the left hemisphere
# --------------------------------------------------------------------------------
# [Step 1] Generating mid-thickness surface and curvature data...
# Hemisphere: lh
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj001/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj001/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0068, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0228, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0228, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0237, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0533, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2996, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0225, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0221, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1594908
# min=0.000, parallel=0.0057, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 7662.540750
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj001/surf/lh.graymid...
# surface expansion took 17 minutes and 12 seconds.
# total integrated curvature = -2.243*4pi (-28.190) --> 3 handles
# ICI = 155.8, FI = 1392.8, variation=22899.396
# writing Gaussian curvature to sub-wlsubj001/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj001/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj001/surf/lh.midthickness.surf.gii.temp50856.white.surf.gii as a surface
# Saving sub-wlsubj001/surf/lh.midthickness.surf.gii.temp50856.pial.surf.gii as a surface
# Saving sub-wlsubj001/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 17 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj006/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj006/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0063, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0246, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0246, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0254, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0559, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.3001, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0240, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0235, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0242, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0242, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0054, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0063, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1603920
# min=0.000, parallel=0.0053, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 7860.329884
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj006/surf/lh.graymid...
# surface expansion took 18 minutes and 2 seconds.
# total integrated curvature = -11.264*4pi (-141.549) --> 12 handles
# ICI = 147.3, FI = 1469.3, variation=23682.481
# writing Gaussian curvature to sub-wlsubj006/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj006/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj006/surf/lh.midthickness.surf.gii.temp53708.white.surf.gii as a surface
# Saving sub-wlsubj006/surf/lh.midthickness.surf.gii.temp53708.pial.surf.gii as a surface
# Saving sub-wlsubj006/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 18 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj007/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj007/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0066, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0240, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0240, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0252, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0533, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2905, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0238, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0235, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0239, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0239, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1607964
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 8006.923892
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj007/surf/lh.graymid...
# surface expansion took 17 minutes and 12 seconds.
# total integrated curvature = -0.237*4pi (-2.975) --> 1 handles
# ICI = 145.3, FI = 1380.7, variation=22324.314
# writing Gaussian curvature to sub-wlsubj007/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj007/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj007/surf/lh.midthickness.surf.gii.temp56382.white.surf.gii as a surface
# Saving sub-wlsubj007/surf/lh.midthickness.surf.gii.temp56382.pial.surf.gii as a surface
# Saving sub-wlsubj007/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 17 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj014/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj014/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0090, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0089, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0244, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0247, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0252, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0566, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2862, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0236, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0231, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0238, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0238, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0081, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0088, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1203080
# min=0.000, parallel=0.0081, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 3203.990746
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj014/surf/lh.graymid...
# surface expansion took 11 minutes and 1 seconds.
# total integrated curvature = -1.466*4pi (-18.424) --> 2 handles
# ICI = 147.9, FI = 1375.6, variation=22369.194
# writing Gaussian curvature to sub-wlsubj014/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj014/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj014/surf/lh.midthickness.surf.gii.temp58125.white.surf.gii as a surface
# Saving sub-wlsubj014/surf/lh.midthickness.surf.gii.temp58125.pial.surf.gii as a surface
# Saving sub-wlsubj014/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 11 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj019/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj019/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0062, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0220, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0219, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0235, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0674, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.3053, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0218, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0213, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0219, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0219, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0055, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1679740
# min=0.000, parallel=0.0054, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 10092.070508
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj019/surf/lh.graymid...
# surface expansion took 21 minutes and 17 seconds.
# total integrated curvature = 2.980*4pi (37.448) --> -2 handles
# ICI = 205.4, FI = 1844.7, variation=30203.454
# writing Gaussian curvature to sub-wlsubj019/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj019/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj019/surf/lh.midthickness.surf.gii.temp61380.white.surf.gii as a surface
# Saving sub-wlsubj019/surf/lh.midthickness.surf.gii.temp61380.pial.surf.gii as a surface
# Saving sub-wlsubj019/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 21 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj023/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj023/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0097, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0091, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0248, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0251, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0258, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0547, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2807, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0239, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0229, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0242, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0242, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0082, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0089, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1227836
# min=0.000, parallel=0.0081, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 3889.239895
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj023/surf/lh.graymid...
# surface expansion took 12 minutes and 21 seconds.
# total integrated curvature = -7.474*4pi (-93.915) --> 8 handles
# ICI = 163.9, FI = 1459.2, variation=24128.451
# writing Gaussian curvature to sub-wlsubj023/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj023/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj023/surf/lh.midthickness.surf.gii.temp63341.white.surf.gii as a surface
# Saving sub-wlsubj023/surf/lh.midthickness.surf.gii.temp63341.pial.surf.gii as a surface
# Saving sub-wlsubj023/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 12 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj042/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj042/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0069, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0066, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0221, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0221, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0231, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0502, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2623, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0219, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0215, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0220, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0220, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0058, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0066, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1667792
# min=0.000, parallel=0.0057, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9531.252251
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj042/surf/lh.graymid...
# surface expansion took 20 minutes and 30 seconds.
# total integrated curvature = -3.950*4pi (-49.643) --> 5 handles
# ICI = 175.6, FI = 1720.4, variation=27690.466
# writing Gaussian curvature to sub-wlsubj042/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj042/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj042/surf/lh.midthickness.surf.gii.temp66507.white.surf.gii as a surface
# Saving sub-wlsubj042/surf/lh.midthickness.surf.gii.temp66507.pial.surf.gii as a surface
# Saving sub-wlsubj042/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 20 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj045/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj045/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0071, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0068, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0217, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0217, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0231, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0515, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2570, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0215, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0212, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0216, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0216, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0068, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1683588
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9991.412667
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj045/surf/lh.graymid...
# surface expansion took 21 minutes and 25 seconds.
# total integrated curvature = -6.575*4pi (-82.620) --> 8 handles
# ICI = 188.2, FI = 1765.2, variation=28763.219
# writing Gaussian curvature to sub-wlsubj045/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj045/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj045/surf/lh.midthickness.surf.gii.temp69820.white.surf.gii as a surface
# Saving sub-wlsubj045/surf/lh.midthickness.surf.gii.temp69820.pial.surf.gii as a surface
# Saving sub-wlsubj045/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 21 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj055/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj055/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0062, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0215, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0215, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0223, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0485, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2594, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0214, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0210, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0215, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0215, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0055, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1665652
# min=0.000, parallel=0.0054, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9377.961075
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj055/surf/lh.graymid...
# surface expansion took 20 minutes and 30 seconds.
# total integrated curvature = -0.754*4pi (-9.471) --> 2 handles
# ICI = 202.8, FI = 1733.2, variation=28801.422
# writing Gaussian curvature to sub-wlsubj055/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj055/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj055/surf/lh.midthickness.surf.gii.temp72999.white.surf.gii as a surface
# Saving sub-wlsubj055/surf/lh.midthickness.surf.gii.temp72999.pial.surf.gii as a surface
# Saving sub-wlsubj055/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 20 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj056/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj056/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0064, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0196, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0196, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0210, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0580, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2700, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0195, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0192, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0196, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0196, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0055, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1712352
# min=0.000, parallel=0.0053, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 10879.847985
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj056/surf/lh.graymid...
# surface expansion took 22 minutes and 59 seconds.
# total integrated curvature = 4.994*4pi (62.751) --> -4 handles
# ICI = 224.6, FI = 2015.5, variation=32963.066
# writing Gaussian curvature to sub-wlsubj056/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj056/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj056/surf/lh.midthickness.surf.gii.temp76528.white.surf.gii as a surface
# Saving sub-wlsubj056/surf/lh.midthickness.surf.gii.temp76528.pial.surf.gii as a surface
# Saving sub-wlsubj056/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 23 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj057/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj057/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0062, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0207, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0206, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0218, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0503, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2708, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0205, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0200, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0206, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0205, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0053, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1651132
# min=0.000, parallel=0.0052, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9069.995393
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj057/surf/lh.graymid...
# surface expansion took 19 minutes and 41 seconds.
# total integrated curvature = -11.687*4pi (-146.864) --> 13 handles
# ICI = 157.3, FI = 1582.7, variation=25475.963
# writing Gaussian curvature to sub-wlsubj057/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj057/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj057/surf/lh.midthickness.surf.gii.temp79586.white.surf.gii as a surface
# Saving sub-wlsubj057/surf/lh.midthickness.surf.gii.temp79586.pial.surf.gii as a surface
# Saving sub-wlsubj057/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 19 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj062/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj062/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0067, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0214, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0214, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0537, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2841, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0212, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0210, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0213, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0213, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1642320
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9114.172700
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj062/surf/lh.graymid...
# surface expansion took 19 minutes and 11 seconds.
# total integrated curvature = 1.769*4pi (22.225) --> -1 handles
# ICI = 179.5, FI = 1673.5, variation=27157.067
# writing Gaussian curvature to sub-wlsubj062/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj062/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj062/surf/lh.midthickness.surf.gii.temp82553.white.surf.gii as a surface
# Saving sub-wlsubj062/surf/lh.midthickness.surf.gii.temp82553.pial.surf.gii as a surface
# Saving sub-wlsubj062/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 19 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj071/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj071/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0067, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0066, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0200, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0200, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0217, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0567, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2869, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0198, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0195, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0199, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0199, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1647428
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9487.241375
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj071/surf/lh.graymid...
# surface expansion took 19 minutes and 25 seconds.
# total integrated curvature = 7.110*4pi (89.353) --> -6 handles
# ICI = 226.0, FI = 1905.0, variation=31687.434
# writing Gaussian curvature to sub-wlsubj071/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj071/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj071/surf/lh.midthickness.surf.gii.temp85542.white.surf.gii as a surface
# Saving sub-wlsubj071/surf/lh.midthickness.surf.gii.temp85542.pial.surf.gii as a surface
# Saving sub-wlsubj071/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 19 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj076/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj076/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0070, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0066, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0208, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0208, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0224, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0512, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2517, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0206, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0202, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0207, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0208, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1693960
# min=0.000, parallel=0.0058, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 10227.219680
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj076/surf/lh.graymid...
# surface expansion took 21 minutes and 57 seconds.
# total integrated curvature = -4.197*4pi (-52.743) --> 5 handles
# ICI = 206.9, FI = 1865.9, variation=30638.462
# writing Gaussian curvature to sub-wlsubj076/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj076/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj076/surf/lh.midthickness.surf.gii.temp88916.white.surf.gii as a surface
# Saving sub-wlsubj076/surf/lh.midthickness.surf.gii.temp88916.pial.surf.gii as a surface
# Saving sub-wlsubj076/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 22 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj079/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj079/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0067, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0064, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0223, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0223, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0233, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0536, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2847, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0221, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0217, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0222, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0223, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0057, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0063, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1630224
# min=0.000, parallel=0.0056, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 8716.836714
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj079/surf/lh.graymid...
# surface expansion took 18 minutes and 32 seconds.
# total integrated curvature = -7.904*4pi (-99.328) --> 9 handles
# ICI = 162.5, FI = 1784.2, variation=28107.151
# writing Gaussian curvature to sub-wlsubj079/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj079/surf/lh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj079/surf/lh.midthickness.surf.gii.temp91816.white.surf.gii as a surface
# Saving sub-wlsubj079/surf/lh.midthickness.surf.gii.temp91816.pial.surf.gii as a surface
# Saving sub-wlsubj079/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 18 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# ...
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj118/surf/rh.graymid...
# surface expansion took 19 minutes and 51 seconds.
# total integrated curvature = -1.868*4pi (-23.476) --> 3 handles
# ICI = 192.3, FI = 1854.2, variation=29945.493
# writing Gaussian curvature to sub-wlsubj118/surf/rh.graymid.K...done.
# writing mean curvature to sub-wlsubj118/surf/rh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj118/surf/rh.midthickness.surf.gii.temp28965.white.surf.gii as a surface
# Saving sub-wlsubj118/surf/rh.midthickness.surf.gii.temp28965.pial.surf.gii as a surface
# Saving sub-wlsubj118/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 20 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj120/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj120/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0067, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0210, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0210, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0223, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0523, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2619, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0208, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0204, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0210, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0209, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1663784
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 9629.493090
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj120/surf/rh.graymid...
# surface expansion took 20 minutes and 30 seconds.
# total integrated curvature = -15.825*4pi (-198.864) --> 17 handles
# ICI = 165.5, FI = 1731.3, variation=27675.926
# writing Gaussian curvature to sub-wlsubj120/surf/rh.graymid.K...done.
# writing mean curvature to sub-wlsubj120/surf/rh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj120/surf/rh.midthickness.surf.gii.temp32132.white.surf.gii as a surface
# Saving sub-wlsubj120/surf/rh.midthickness.surf.gii.temp32132.pial.surf.gii as a surface
# Saving sub-wlsubj120/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 20 minutes
# [Step 1.1] Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj126/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj126/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0060, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0234, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0518, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2778, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0225, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0221, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0225, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0054, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0058, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1632096
# min=0.000, parallel=0.0053, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 8572.524384
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj126/surf/rh.graymid...
# surface expansion took 18 minutes and 39 seconds.
# total integrated curvature = -12.790*4pi (-160.730) --> 14 handles
# ICI = 154.5, FI = 1521.4, variation=24654.670
# writing Gaussian curvature to sub-wlsubj126/surf/rh.graymid.K...done.
# writing mean curvature to sub-wlsubj126/surf/rh.graymid.H...done.
# Mid-thickness surface has been generated.
# [Step 1.2] Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj126/surf/rh.midthickness.surf.gii.temp35042.white.surf.gii as a surface
# Saving sub-wlsubj126/surf/rh.midthickness.surf.gii.temp35042.pial.surf.gii as a surface
# Saving sub-wlsubj126/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native data to fsaverage space...
# Data resampling is complete.
# Execution time: 18 minutes
# --------------------------------------------------------------------------------
# Map: polarAngle
# --------------------------------------------------------------------------------
# [Step 2] Retinotopy prediction...
# Processing...
# Done!
# [Step 2.1] Loading the dataset
# Dataset loaded
# Time elapsed: 0.30530349165201187 minutes
# [Step 2.2] Generating predictions with pre-trained models
# Loading model 1
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj001/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj006/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj007/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj014/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj019/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj023/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj042/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj045/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj055/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj056/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj057/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj062/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj071/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj076/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj079/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj081/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj083/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj084/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj086/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj088/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj091/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj094/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj095/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj104/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj114/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj115/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj116/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj117/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj118/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj120/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj126/deepRetinotopy/
# Predictions from model 1 were saved
# Time elapsed: 7.9421867951750755 minutes
# --------------------------------------------------------------------------------
# [Step 3] Resampling predictions to native space...
# Model: model
# polarAngle predictions resampling for rh is done!
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Map: eccentricity
# --------------------------------------------------------------------------------
# [Step 2] Retinotopy prediction...
# Processing...
# Done!
# [Step 2.1] Loading the dataset
# Dataset loaded
# Time elapsed: 0.30050430074334145 minutes
# [Step 2.2] Generating predictions with pre-trained models
# Loading model 1
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj001/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj006/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj007/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj014/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj019/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj023/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj042/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj045/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj055/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj056/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj057/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj062/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj071/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj076/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj079/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj081/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj083/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj084/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj086/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj088/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj091/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj094/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj095/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj104/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj114/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj115/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj116/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj117/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj118/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj120/deepRetinotopy/
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test2/sub-wlsubj126/deepRetinotopy/
# Predictions from model 1 were saved
# Time elapsed: 7.961683847010136 minutes
# --------------------------------------------------------------------------------
# [Step 3] Resampling predictions to native space...
# Model: model
# eccentricity predictions resampling for rh is done!
# --------------------------------------------------------------------------------
# All done!
# Runtime: 74035.972488 seconds
