# %%
mris_convert $dirSub/surf/"$hemisphere".white $dirSub/surf/"$hemisphere".white.gii
mris_convert $dirSub/surf/"$hemisphere".pial $dirSub/surf/"$hemisphere".pial.gii
midthickness_surf.py --path $dirSub/surf/ --hemisphere $hemisphere # add to PATH
mris_convert $dirSub/surf/"$hemisphere".graymid.gii $dirSub/surf/"$hemisphere".graymid
mris_curvature -w $dirSub/surf/"$hemisphere".graymid

# %%
import lmod
await lmod.load('deepretinotopy/1.0.8')
import os

# %%
os.environ["hemisphere"] = "lh"
os.environ["dirSub"] = '/neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001'

# %%
# !mris_convert $dirSub/surf/"$hemisphere".white $dirSub/surf/"$hemisphere".white.gii
# Out:
# Saving /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/surf/lh.white.gii as a surface

# %%
# !mris_convert $dirSub/surf/"$hemisphere".pial $dirSub/surf/"$hemisphere".pial.gii
# Out:
# Saving /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/surf/lh.pial.gii as a surface

# %%
# !utils/midthickness_surf.py --path $dirSub/surf/ --hemisphere $hemisphere # add to PATH
# Out:
# Midthickness surface saved at /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/surf/lh.graymid.gii

# %%
# %%bash
# hemisphere="lh"
# dirSub='/neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001'
# utils/midthickness_surf.py --path $dirSub/surf/ --hemisphere $hemisphere
# Out:
# bash: utils/midthickness_surf.py: /usr/bin/env: bad interpreter: Permission denied
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'hemisphere="lh"\ndirSub=\'/neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001\'\nutils/midthickness_surf.py --path $dirSub/surf/ --hemisphere $hemisphere\n')
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/magics/script.py:155, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     153 else:
#     154     line = script
# --> 155 return self.shebang(line, cell)
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/magics/script.py:315, in ScriptMagics.shebang(self, line, cell)
#     310 if args.raise_error and p.returncode != 0:
#     311     # If we get here and p.returncode is still None, we must have
#     312     # killed it but not yet seen its return code. We don't wait for it,
#     313     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     314     rc = p.returncode or -9
# --> 315     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'hemisphere="lh"\ndirSub=\'/neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001\'\nutils/midthickness_surf.py --path $dirSub/surf/ --hemisphere $hemisphere\n'' returned non-zero exit status 126.
