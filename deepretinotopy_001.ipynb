# %%
import lmod

# %%
await lmod.load('deepretinotopy/1.0.5')

# %%
# !deepRetinotopy

# %%
# !deepRetinotopy -s /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/ \
                -t /neurodesktop-storage/HCPpipelines-master/global/templates/standard_mesh_atlases/resample_fsaverage/ \
                -d nyu \
                -m "polarAngle,eccentricity"
# Out:
# Path subs directory: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Path to fs_LR-deformed_to-fsaverage surfaces: /neurodesktop-storage/HCPpipelines-master/global/templates/standard_mesh_atlases/resample_fsaverage/
# Dataset name: nyu
# Maps: polarAngle eccentricity
# Generating mid-thickness surface and curvature data...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Subject: sub-wlsubj001
# Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj001/surf/lh.white by 50.0% of thickness and writing it to sub-wlsubj001/surf/lh.graymid
# reading thickness...
# min=0.000, parallel=0.0068, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0228, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0228, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0237, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0533, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.2996, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0225, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0221, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0226, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0065, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1594912
# min=0.000, parallel=0.0057, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 7662.540750
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj001/surf/lh.graymid...
# surface expansion took 17 minutes and 58 seconds.
# total integrated curvature = -2.243*4pi (-28.190) --> 3 handles
# ICI = 155.8, FI = 1392.8, variation=22899.396
# writing Gaussian curvature to sub-wlsubj001/surf/lh.graymid.K...done.
# writing mean curvature to sub-wlsubj001/surf/lh.graymid.H...done.
# Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj001/surf/lh.midthickness.surf.gii.temp49640.white.surf.gii as a surface
# Saving sub-wlsubj001/surf/lh.midthickness.surf.gii.temp49640.pial.surf.gii as a surface
# Saving sub-wlsubj001/surf/lh.sphere.reg.surf.gii as a surface
# Resampling native to fsaverage space...
# Execution time: 20 minutes
# Retinotopy prediction...
# /opt/miniconda-py37_4.8.3/lib/python3.7/site-packages/torch_geometric/nn/conv/spline_conv.py:118: UserWarning: We do not recommend using the non-optimized CPU version of `SplineConv`. If possible, please move your data to GPU.
#   'We do not recommend using the non-optimized CPU version of '
# Loading the dataset
# Processing...
# Done!
# Dataset loaded
# Time elapsed: 0.3699878975749016 minutes
# Loading model 1
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 1 were saved
# Time elapsed: 3.9191774241626263 minutes
# Loading model 2
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 2 were saved
# Time elapsed: 3.119643736630678 minutes
# Loading model 3
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 3 were saved
# Time elapsed: 3.4684832766652107 minutes
# Loading model 4
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 4 were saved
# Time elapsed: 3.670329872518778 minutes
# Loading model 5
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 5 were saved
# Time elapsed: 4.254544902592897 minutes
# Saving average predictions
# Average predictions were saved
# Resampling predictions to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: polarAngle
# Model: model1
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: polarAngle
# Model: model2
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: polarAngle
# Model: model3
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: polarAngle
# Model: model4
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: polarAngle
# Model: model5
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: polarAngle
# Model: average
# Resampling fsaverage to native space...
# polarAngle predictions for lh are done!
# Retinotopy prediction...
# Loading the dataset
# Processing...
# Done!
# Dataset loaded
# Time elapsed: 0.3092151805758476 minutes
# Loading model 1
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 1 were saved
# Time elapsed: 4.654842123389244 minutes
# Loading model 2
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 2 were saved
# Time elapsed: 3.691537171602249 minutes
# Loading model 3
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 3 were saved
# Time elapsed: 3.9221808165311813 minutes
# Loading model 4
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 4 were saved
# Time elapsed: 3.7943862341344357 minutes
# Loading model 5
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 5 were saved
# Time elapsed: 4.098539628088474 minutes
# Saving average predictions
# Average predictions were saved
# /opt/miniconda-py37_4.8.3/lib/python3.7/site-packages/torch_geometric/nn/conv/spline_conv.py:118: UserWarning: We do not recommend using the non-optimized CPU version of `SplineConv`. If possible, please move your data to GPU.
#   'We do not recommend using the non-optimized CPU version of '
# Resampling predictions to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: eccentricity
# Model: model1
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: eccentricity
# Model: model2
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: eccentricity
# Model: model3
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: eccentricity
# Model: model4
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: eccentricity
# Model: model5
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: lh
# Map: eccentricity
# Model: average
# Resampling fsaverage to native space...
# eccentricity predictions for lh are done!
# Generating mid-thickness surface and curvature data...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Subject: sub-wlsubj001
# Generating mid-thickness surface and curvature data if not available...
# using distance as a % of thickness
# expanding surface sub-wlsubj001/surf/rh.white by 50.0% of thickness and writing it to sub-wlsubj001/surf/rh.graymid
# reading thickness...
# min=0.000, parallel=0.0061, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0219, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0219, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0230, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0559, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.3075, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0217, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0213, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0218, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0218, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0054, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# min=0.000, parallel=0.0059, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# -01: dt=0.0000,   0 negative triangles  VmPeak 1592712
# min=0.000, parallel=0.0054, normal=0.0000, spring=0.0000, ashburner=0.000, tsmooth=0.000
# ending sse = 7604.399418
# nrounds = 6
# ***************** integrating with averages = 16, niter = 40, l_spring = 0.000 ***********************
# step 40 of 240     ***************** integrating with averages = 8, niter = 40, l_spring = 0.000 ***********************
# step 80 of 240     ***************** integrating with averages = 4, niter = 40, l_spring = 0.000 ***********************
# step 120 of 240     ***************** integrating with averages = 2, niter = 40, l_spring = 0.000 ***********************
# step 160 of 240     ***************** integrating with averages = 1, niter = 40, l_spring = 0.000 ***********************
# step 200 of 240     ***************** integrating with averages = 0, niter = 40, l_spring = 0.000 ***********************
# step 240 of 240
# writing expanded surface to sub-wlsubj001/surf/rh.graymid...
# surface expansion took 22 minutes and 5 seconds.
# total integrated curvature = -3.729*4pi (-46.856) --> 5 handles
# ICI = 150.2, FI = 1375.7, variation=22523.944
# writing Gaussian curvature to sub-wlsubj001/surf/rh.graymid.K...done.
# writing mean curvature to sub-wlsubj001/surf/rh.graymid.H...done.
# Preparing native surfaces for resampling if not available...
# Saving sub-wlsubj001/surf/rh.midthickness.surf.gii.temp73613.white.surf.gii as a surface
# Saving sub-wlsubj001/surf/rh.midthickness.surf.gii.temp73613.pial.surf.gii as a surface
# Saving sub-wlsubj001/surf/rh.sphere.reg.surf.gii as a surface
# Resampling native to fsaverage space...
# Execution time: 22 minutes
# Retinotopy prediction...
# /opt/miniconda-py37_4.8.3/lib/python3.7/site-packages/torch_geometric/nn/conv/spline_conv.py:118: UserWarning: We do not recommend using the non-optimized CPU version of `SplineConv`. If possible, please move your data to GPU.
#   'We do not recommend using the non-optimized CPU version of '
# Loading the dataset
# Processing...
# Done!
# Dataset loaded
# Time elapsed: 0.42863723635673523 minutes
# Loading model 1
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 1 were saved
# Time elapsed: 4.78933047875762 minutes
# Loading model 2
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 2 were saved
# Time elapsed: 4.260667033493519 minutes
# Loading model 3
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 3 were saved
# Time elapsed: 4.019698549062014 minutes
# Loading model 4
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 4 were saved
# Time elapsed: 3.707814335823059 minutes
# Loading model 5
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 5 were saved
# Time elapsed: 4.062028553336859 minutes
# Saving average predictions
# Average predictions were saved
# Resampling predictions to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: polarAngle
# Model: model1
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: polarAngle
# Model: model2
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: polarAngle
# Model: model3
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: polarAngle
# Model: model4
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: polarAngle
# Model: model5
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: polarAngle
# Model: average
# Resampling fsaverage to native space...
# polarAngle predictions for rh are done!
# Retinotopy prediction...
# /opt/miniconda-py37_4.8.3/lib/python3.7/site-packages/torch_geometric/nn/conv/spline_conv.py:118: UserWarning: We do not recommend using the non-optimized CPU version of `SplineConv`. If possible, please move your data to GPU.
#   'We do not recommend using the non-optimized CPU version of '
# Loading the dataset
# Processing...
# Done!
# Dataset loaded
# Time elapsed: 0.3715655729174614 minutes
# Loading model 1
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 1 were saved
# Time elapsed: 4.117967452853918 minutes
# Loading model 2
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 2 were saved
# Time elapsed: 3.65856521576643 minutes
# Loading model 3
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 3 were saved
# Time elapsed: 3.7833828888833523 minutes
# Loading model 4
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 4 were saved
# Time elapsed: 3.526548657566309 minutes
# Loading model 5
# Saving .gii files in: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/sub-wlsubj001/deepRetinotopy/
# Predictions from model 5 were saved
# Time elapsed: 3.7518065720796585 minutes
# Saving average predictions
# Average predictions were saved
# Resampling predictions to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: eccentricity
# Model: model1
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: eccentricity
# Model: model2
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: eccentricity
# Model: model3
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: eccentricity
# Model: model4
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: eccentricity
# Model: model5
# Resampling fsaverage to native space...
# Path: /neurodesktop-storage/nyu_retinotopy_data/freesurfer_test/
# Hemisphere: rh
# Map: eccentricity
# Model: average
# Resampling fsaverage to native space...
# eccentricity predictions for rh are done!
# All done!
